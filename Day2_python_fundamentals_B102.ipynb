# %%
print("Hello world!")   # input cell.
# Out:
# Hello world!

# %%
Introduction to python programming

# %%
understanding the variables in python :

# %%
a = 20

b = 30

# %%
c = a+b

print(c)
# Out:
# 50

# %%
Rules for declaring the variables :

# %%
Rule No 1 : No namespaces for declaring the variables.

# %%
first name = "Syed"

print(first name)
# Out:
#   Cell In[4], line 1
#     first name = "Syed"
#           ^
# SyntaxError: invalid syntax

# %%
firstname = 'Syed'

print(firstname)
# Out:
# Syed

# %%
first_name = 'Syed'

print(first_name)
# Out:
# Syed

# %%
Rule No 2 : A variable name should not start with a number  **

# %%
1name = 'rahul'

print(1name)
# Out:
#   Cell In[7], line 1
#     1name = 'rahul'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'sameer'

print(name1)
# Out:
# sameer

# %%
Rule No 3 : A variable name should not contain any special characters

# %%
@ # $ % & *

# %%
name@ = 'rani'

print(name@)
# Out:
#   Input In [9]
#     name@ = 'Nandini'
#           ^
# SyntaxError: invalid syntax

# %%
Introduction to  Datatypes in python :
    
    1. Strings -----------> str
    2.Numbers -----> integers( int) and float( decimals 0.1,0.2)
    3. lists ---> list
    4. tuples ---> tuple
    5. dictionaries ----> dict

# %%
Note : python is a case sensitive programming lanuage ..

# %%
classification of datatypes :
    
    Broadly datatypes are classified in two catgeories :
        
        1. mutable datatypes -----> which we can edit / alter ---> flexible in nature
        
        2. immutable datatypes ----> which we cannot be able to edit -----> fixed in nature.

# %%
introduction to string datatype :

# %%
defination : A string is nothing but a series of characters declared in quotes.
    
classification : It is classifed as an immutable datatype
    
how to define the string ? ----> two apporaches :
    
    1. single quote
    
    2. double quote

# %%
name = 'anil'  # single quote

print(name)
# Out:
# anil

# %%
name2 = "tausif"  # double quote

print(name2)
# Out:
# tausif
